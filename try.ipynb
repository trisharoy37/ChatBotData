# %%
import pytest
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup as bs
from selenium.webdriver.support.ui import WebDriverWait
import re
import pandas as pd
from selenium.webdriver.support import expected_conditions as EC
import os
from chromedriver_py import binary_path # this will get you the path variable

# svc = webdriver.ChromeService(executable_path=binary_path)
# driver = webdriver.Chrome(service=svc)
class TestTry1():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = webdriver.ChromeService(executable_path=binary_path)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}
  
  def teardown_method(self, method):
    self.driver.quit()
  
  def wait_for_window(self, timeout = 2):
    time.sleep(round(timeout / 1000))
    wh_now = self.driver.window_handles
    wh_then = self.vars["window_handles"]
    if len(wh_now) > len(wh_then):
      return set(wh_now).difference(set(wh_then)).pop()
  
  def test_try1(self):
    self.driver.get("https://ums.lpu.in/lpuums/LoginNew.aspx")
    self.driver.set_window_size(768, 864)
    # self.driver.find_element(By.ID, "txtU").click()
    self.driver.find_element(By.ID, "txtU").send_keys("12107768")
    try:
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Singh123@")
    except Exception as e:
      #print(f"Error finding or clicking submit button: {e}")
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Singh123@")
    
    self.driver.find_element(By.ID, "iBtnLogins150203125").click()
    # element = self.driver.find_element(By.ID, "chkReadMessage")

    try:
      element = WebDriverWait(self.driver, 10).until(EC.element_to_be_clickable((By.ID, "chkReadMessage")))
      if element:
        try:
          actions = ActionChains(self.driver)
          actions.move_to_element(element).perform()
          element.click()  # Click on the element directly (without find_element again)
        except Exception as e:
          print("Element with ID 'chkReadMessage' not found or not interactable within 10 seconds.")

        try:
          element = WebDriverWait(self.driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "enableClosedialog")))
          actions = ActionChains(self.driver)
          actions.move_to_element(element).perform()
          element.click()  # Click on the element directly (without find_element again)

        except Exception as e:
          element = WebDriverWait(self.driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "enableClosedialog")))
          actions = ActionChains(self.driver)
          actions.move_to_element(element).perform()
          element.click()
          print("Element with ID 'chkReadMessage' not found or not interactable within 10 seconds.",e)
      else:
        print("Element with ID 'chkReadMessage' not found. Skipping actions.")
    except Exception as e:
      print("Element with ID 'chkReadMessage' not found or not interactable within 10 seconds.")

    
  

    self.driver.execute_script("window.scrollTo(0,90.4000015258789)")
    self.driver.execute_script("window.scrollTo(0,1744.800048828125)")
    self.driver.execute_script("window.scrollTo(0,1972.800048828125)")
    self.vars["window_handles"] = self.driver.window_handles
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.LINK_TEXT, "View All Announcements"))
      )
      element.click()
    except:
      driver.quit()
    self.vars["win8781"] = self.wait_for_window(2000)
    self.driver.switch_to.window(self.vars["win8781"])
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_txtSubject").click()
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_txtSubject").send_keys("Exam")
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_btnShow").click()

    cont=self.driver.page_source
    cont_html = bs(cont, "html.parser")
    # print(cont_html)
    commentboxes1 = cont_html.find_all('tr', {'class': "rgRow"})
    list1=[]
    for comment in commentboxes1:
      k=comment.text
      cleaned_text = re.sub(r"\s+", " ", k)
      cleaned_text = cleaned_text.replace("\xa0", " ")
      list1.append(cleaned_text)
      
    commentboxes2 = cont_html.find_all('tr', {'class': "rgAltRow"})
    for comment in commentboxes2:
      k=comment.text
      cleaned_text = re.sub(r"\s+", " ", k)
      cleaned_text = cleaned_text.replace("\xa0", " ")
      list1.append(cleaned_text)
      # print(k)
    
    with open("comments.txt", "w", encoding="utf-8") as text_file:
      for item in list1:
        text_file.write(item + "\n")  # Add newline character for readability

    
  
if __name__ == '__main__':
  DRIVER_PATH = r"chromedriver.exe"
  browser = TestTry1(DRIVER_PATH)
  browser.test_try1()

# %%
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup as bs
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
import re
import pandas as pd

from selenium.webdriver.support import expected_conditions as EC

class TestTry1():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()

  def wait_for_window(self, timeout = 2):
    time.sleep(round(timeout / 1000))
    wh_now = self.driver.window_handles
    wh_then = self.vars["window_handles"]
    if len(wh_now) > len(wh_then):
        return set(wh_now).difference(set(wh_then)).pop()
  
  def test_wes(self):
    self.driver.get("https://ums.lpu.in/lpuums/LoginNew.aspx")
    self.driver.set_window_size(768, 864)
    # self.driver.find_element(By.ID, "txtU").click()
    self.driver.find_element(By.ID, "txtU").send_keys("12101718")
    try:
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    except Exception as e:
      #print(f"Error finding or clicking submit button: {e}")
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    self.driver.find_element(By.ID, "iBtnLogins150203125").click()
    self.vars["window_handles"] = self.driver.window_handles
    try:
      element=WebDriverWait(self.driver,5).until(
      EC.presence_of_element_located((By.LINK_TEXT, "RMS"))
      )
      element.click()
    except:
      self.driver.quit()
    # self.driver.find_element(By.LINK_TEXT, "RMS").click()
    self.vars["win3589"] = self.wait_for_window(2000)
    self.driver.switch_to.window(self.vars["win3589"])
    self.driver.find_element(By.ID, "btnagreeterms").click()
    self.driver.find_element(By.CSS_SELECTOR, ".modal-footer > .btn").click()
    self.driver.find_element(By.ID, "rblmessagetype_0").click()
    with open("RMS_Academic_Administrative_Issues.txt", "w", encoding="utf-8") as text_file:
      cont=self.driver.page_source
      cont_html = bs(cont, "html.parser")
      commentboxes1 = cont_html.find_all('select', {'class': "aspDropDownList"})
      text=commentboxes1[0].text
      lines=text.splitlines()
      text_file.write("Master Category list:" + "\n\n")
      # print()
      for i in lines[2:]:
        text_file.write(i+ "\n")
        # print(i)
      for i in lines[2:]:
        pp = self.driver.find_element(By.ID, "ddlMCategory")  # Re-find the element
        okay = Select(pp)
        okay.select_by_value(i)
        time.sleep(3)
        cont = self.driver.page_source
        cont_html = bs(cont, "html.parser")
        commentboxes2 = cont_html.find_all('select', {'class': "aspDropDownList"})
        text1 = commentboxes2[1].text
        # print("Master Category:",i)
        # print("Category List:",text1)
        text_file.write("\n\nMaster Category:"+ i)
        
        lines2=text1.splitlines()
        text_file.write("Category list:\n")
        for i in lines2[2:]:
          text_file.write(i+ "\n")
        for i in lines2[2:]:
          try:
            cc = self.driver.find_element(By.ID, "ddlCategory")
            abe = Select(cc)
            abe.select_by_visible_text(i)
            time.sleep(3)

            cont = self.driver.page_source
            cont_html = bs(cont, "html.parser")
            commentboxes3 = cont_html.find_all('select', {'class': "aspDropDownList"})
            text2 = commentboxes3[2].text
            text_file.write("Category Selected:"+ i + "\n")
            # print("Category Selected:", i)
            cont = self.driver.page_source
            cont_html = bs(cont, "html.parser")
            about = cont_html.find('div', {'id': "trdesc"})
            if about:  # Check if the element exists
                # Access the text directly if there's a p tag as the first child
              if about.find('p'):
                text_file.write("Information:"+ about.find('p').text + "\n")
                print("Information:", about.find('p').text)
              else:
                pass
              if about.find('ul'):

                data=about.find('ul')
                maindata=data.find_all('li')
                
                for i in maindata:
                  # print("*",i.text)
                  text_file.write("*"+i.text + "\n")
            else:
              pass

            text_file.write("Subcategory List:"+ text2 + "\n\n\n")
            # print("Subcategory List", text2)
          except Exception as e :
            print(f"Element with visible text '{i}' not found in dropdown. Skipping.")

    
      

  
if __name__ == '__main__':
    DRIVER_PATH = r"chromedriver.exe"
    browser = TestTry1(DRIVER_PATH)
    browser.test_wes()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd

options = Options()

DRIVER_PATH = r"chromedriver.exe"

service = Service(DRIVER_PATH)
driver = webdriver.Chrome(options=options, service=service)

driver.get("https://www.lpu.in/academics/holiday-list.php")
cont=driver.page_source
cont_html = bs(cont, "html.parser")
# print(cont_html)
commentboxes1 = cont_html.find_all('th')
d={}
header=[]
for i in commentboxes1:
    d[i.text]=list()
    header.append(i.text)
commentboxes2 = cont_html.find_all('td')
# print(header)
k=0
mn=[]
for i in commentboxes2:
    mn.append(i.text)
    if k==3:
        k=0
    d[header[k]].append(i.text)
    k+=1
print(d)
# print(df)
df=pd.DataFrame(d)
with open("holidays.txt", "w", encoding="utf-8") as text_file:
    text_file.write(df.to_string()+"\n\n")
# Out:
# {'Holiday/Occasion/Festival': [' Birthday of Sri Guru Gobind Singh Ji ', ' Republic Day ', ' Sri Guru Ravi Dass Jayanti ', ' Holi ', ' Id-ul-Fitr* ', ' Id-ul-Zuha (Bakrid)* ', ' Independence Day ', ' Mahatma Gandhi Jayanti ', ' Dussehra ', ' Birthday of Maharishi Valmiki Ji ', ' Diwali ', ' Birthday of Sri Guru Nanak Dev Ji ', ' Christmas '], 'Date': [' 17thJanuary ', ' 26th January ', ' 24th February ', ' 25th March ', ' 11th April ', ' 17thJune ', ' 15th August ', ' 2nd October ', ' 12th October ', ' 17th October ', ' 31st October ', ' 15th November ', ' 25th December '], 'Day': [' Wednesday ', ' Friday ', ' Saturday ', ' Monday ', ' Thursday ', ' Monday ', ' Thursday ', ' Wednesday ', ' Saturday ', ' Thursday ', ' Thursday ', ' Friday ', ' Wednesday ']}

# %%
df
# Out:
#                  Holiday/Occasion/Festival             Date          Day
# 0    Birthday of Sri Guru Gobind Singh Ji      17thJanuary    Wednesday
# 1                            Republic Day     26th January       Friday
# 2              Sri Guru Ravi Dass Jayanti    24th February     Saturday
# 3                                    Holi       25th March       Monday
# 4                             Id-ul-Fitr*       11th April     Thursday
# 5                    Id-ul-Zuha (Bakrid)*         17thJune       Monday
# 6                        Independence Day      15th August     Thursday
# 7                  Mahatma Gandhi Jayanti      2nd October    Wednesday
# 8                                Dussehra     12th October     Saturday
# 9        Birthday of Maharishi Valmiki Ji     17th October     Thursday
# 10                                 Diwali     31st October     Thursday
# 11      Birthday of Sri Guru Nanak Dev Ji    15th November       Friday
# ...

# %%
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup as bs
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
import re
import pandas as pd

from selenium.webdriver.support import expected_conditions as EC

class TestTry1():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()

  def wait_for_window(self, timeout = 2):
    time.sleep(round(timeout / 1000))
    wh_now = self.driver.window_handles
    wh_then = self.vars["window_handles"]
    if len(wh_now) > len(wh_then):
        return set(wh_now).difference(set(wh_then)).pop()
  
  def test_wes(self):
    self.driver.get("https://ums.lpu.in/lpuums/LoginNew.aspx")
    self.driver.set_window_size(768, 864)
    # self.driver.find_element(By.ID, "txtU").click()
    self.driver.find_element(By.ID, "txtU").send_keys("12101718")
    try:
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    except Exception as e:
      #print(f"Error finding or clicking submit button: {e}")
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    self.driver.find_element(By.ID, "iBtnLogins150203125").click()
    self.vars["window_handles"] = self.driver.window_handles
    try:
      element=WebDriverWait(self.driver,5).until(
      EC.presence_of_element_located((By.LINK_TEXT, "RMS"))
      )
      element.click()
    except:
      self.driver.quit()
    # self.driver.find_element(By.LINK_TEXT, "RMS").click()
    self.vars["win3589"] = self.wait_for_window(2000)
    self.driver.switch_to.window(self.vars["win3589"])
    self.driver.find_element(By.ID, "btnagreeterms").click()
    self.driver.find_element(By.CSS_SELECTOR, ".modal-footer > .btn").click()
    self.driver.find_element(By.ID, "rblmessagetype_0").click()
    with open("RMS_Academic_Administrative_Issues.txt", "w", encoding="utf-8") as text_file:
      cont=self.driver.page_source
      cont_html = bs(cont, "html.parser")
      commentboxes1 = cont_html.find_all('select', {'class': "aspDropDownList"})
      text=commentboxes1[0].text
      lines=text.splitlines()
      text_file.write("Master Category list:" + "\n\n")
      # print()
      for i in lines[2:]:
        text_file.write(i+ "\n")
        # print(i)
      for i in lines[2:]:
        pp = self.driver.find_element(By.ID, "ddlMCategory")  # Re-find the element
        okay = Select(pp)
        okay.select_by_value(i)
        time.sleep(3)
        cont = self.driver.page_source
        cont_html = bs(cont, "html.parser")
        commentboxes2 = cont_html.find_all('select', {'class': "aspDropDownList"})
        text1 = commentboxes2[1].text
        # print("Master Category:",i)
        # print("Category List:",text1)
        text_file.write("\n\nMaster Category:"+ i)
        
        lines2=text1.splitlines()
        text_file.write("Category list:\n")
        for i in lines2[2:]:
          text_file.write(i+ "\n")
        for i in lines2[2:]:
          try:
            cc = self.driver.find_element(By.ID, "ddlCategory")
            abe = Select(cc)
            abe.select_by_visible_text(i)
            time.sleep(3)

            cont = self.driver.page_source
            cont_html = bs(cont, "html.parser")
            commentboxes3 = cont_html.find_all('select', {'class': "aspDropDownList"})
            text2 = commentboxes3[2].text
            text_file.write("Category Selected:"+ i + "\n")
            # print("Category Selected:", i)
            cont = self.driver.page_source
            cont_html = bs(cont, "html.parser")
            about = cont_html.find('div', {'id': "trdesc"})
            if about:  # Check if the element exists
                # Access the text directly if there's a p tag as the first child
              if about.find('p'):
                text_file.write("Information:"+ about.find('p').text + "\n")
                print("Information:", about.find('p').text)
              else:
                pass
              if about.find('ul'):

                data=about.find('ul')
                maindata=data.find_all('li')
                
                for i in maindata:
                  # print("*",i.text)
                  text_file.write("*"+i.text + "\n")
            else:
              pass

            text_file.write("Subcategory List:"+ text2 + "\n\n\n")
            # print("Subcategory List", text2)
          except Exception as e :
            print(f"Element with visible text '{i}' not found in dropdown. Skipping.")

    
      

  
if __name__ == '__main__':
    DRIVER_PATH = r"chromedriver.exe"
    browser = TestTry1(DRIVER_PATH)
    browser.test_wes()
# Out:
# Information: Division of Academic Affairs (DAA) is a Central Division located in Block-29 Room No-404.The division frames academic policies, systems and processes that support Faculty members and students in all aspects related to academic planning, curriculum, teaching, learning and other academic systems. The primary areas with which Division of Academic Affairs deals are as follows:
# Information: Division of Admissions is a central division located in Block-30 (Basement) and is committed to support freshmen by providing solutions to the issues faced during the admission process and their reporting at university campus. The concerns with which Division of Admissions mainly deals are as follows:
# ...

# %%
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup as bs
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
import re
import pandas as pd

from selenium.webdriver.support import expected_conditions as EC

class TestTry1():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()

  def wait_for_window(self, timeout = 2):
    time.sleep(round(timeout / 1000))
    wh_now = self.driver.window_handles
    wh_then = self.vars["window_handles"]
    if len(wh_now) > len(wh_then):
        return set(wh_now).difference(set(wh_then)).pop()
  
  def test_wes(self):
    self.driver.get("https://ums.lpu.in/lpuums/LoginNew.aspx")
    self.driver.set_window_size(768, 864)
    # self.driver.find_element(By.ID, "txtU").click()
    self.driver.find_element(By.ID, "txtU").send_keys("12101718")
    try:
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    except Exception as e:
      #print(f"Error finding or clicking submit button: {e}")
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    self.driver.find_element(By.ID, "iBtnLogins150203125").click()
    self.vars["window_handles"] = self.driver.window_handles
    try:
      element=WebDriverWait(self.driver,5).until(
      EC.presence_of_element_located((By.LINK_TEXT, "RMS"))
      )
      element.click()
    except:
      self.driver.quit()
    # self.driver.find_element(By.LINK_TEXT, "RMS").click()
    self.vars["win3589"] = self.wait_for_window(2000)
    self.driver.switch_to.window(self.vars["win3589"])
    self.driver.find_element(By.ID, "btnagreeterms").click()
    self.driver.find_element(By.CSS_SELECTOR, ".form-check:nth-child(2) > .containerradio").click()
    self.driver.find_element(By.CSS_SELECTOR, ".modal-footer > .btn").click()
    cont=self.driver.page_source
    cont_html = bs(cont, "html.parser")
    commentboxes1 = cont_html.find_all('select', {'class': "aspDropDownList"})
    text=commentboxes1[0].text
    print("Master Category list:",text)
    lines=text.splitlines()
    print(type(lines))
    print(type(lines[0]))
    # print(lines[2:])
    for i in lines[2:]:
      try:
        pp = self.driver.find_element(By.ID, "ddlSubCategory")  # Re-find the element
        okay = Select(pp)
        okay.select_by_visible_text(i)
        time.sleep(3)
        cont = self.driver.page_source
        cont_html = bs(cont, "html.parser")
        commentboxes2 = cont_html.find_all('select', {'class': "aspDropDownList"})
        text1 = commentboxes2[1].text
        print("Master Category:",i,"\nSubcategory",text1)
      except Exception as e:
        print(f"Element with visible text '{i}' not found in dropdown. Skipping.")
        continue
      lines2=text1.splitlines()
      for i in lines2[2:]:
        try:
          cc = self.driver.find_element(By.ID, "ddlSpecificCategory")
          abe = Select(cc)
          abe.select_by_visible_text(i)
          time.sleep(3)

          cont = self.driver.page_source
          cont_html = bs(cont, "html.parser")
          commentboxes3 = cont_html.find_all('select', {'class': "aspDropDownList"})
          text2 = commentboxes3[2].text
          print("Subcategory:", i, text2)
          cont = self.driver.page_source
          cont_html = bs(cont, "html.parser")
          about = cont_html.find('div', {'id': "trdesc"})
          if about:  # Check if the element exists
              # Access the text directly if there's a p tag as the first child
            if about.find('p'):
              print("Main data:", about.find('p').text)
            else:
              print("No 'p' tag found within the div with id:trdesc")
          else:
            print("Div with id:trdesc not found")
        except Exception as e :
          print(f"Element with visible text '{i}' not found in dropdown. Skipping.")

    
      

  
if __name__ == '__main__':
    DRIVER_PATH = r"chromedriver.exe"
    browser = TestTry1(DRIVER_PATH)
    browser.test_wes()
# Out:
# Master Category list:
# Select
# Air Conditioner
# Carpentry.
# Desert Cooler/Air Cooler (Electrical)
# Desert Coolor/Air Cooler (Plumbing)
# Electricity
# Energy Meter
# Gas Welder
# Lift
# Marking
# Mason
# Plumbing
# Sewerage
# Tailor
# Water Cooler/Drinking water(Cooling Issue)
# Water Cooler/Drinking water(Electrical Issue)
# Water Cooler/Drinking water(Plumbing Issue)
# Water Purifier / RO System
# Welding
#
# <class 'list'>
# <class 'str'>
# Master Category: Air Conditioner
# Subcategory
# Select
# Split A.C not working
# Window AC not working
#
# Subcategory: Split A.C not working
# Select
# 1A-School of Design (Fashion)
# 1B-School of Design (Fashion)
# 2A-Uni Auditorium
# 3-Uni-Health Center
# 4-Lovely Institute of Technology-Pharmacy
# 5-Animal House
# 6-School of Architeture & Designing
# 7-School of Pharmaceutical Secience
# 8-School of Journalism,Film Production and Creative Arts
# 00-Main Gate 1
# 13-Student Welfare Wing
# 14-School of Business
# 15-Uni Mall
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup as bs
import time
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
import pytest
import time
import json
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import requests





class TestResidentialServices():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()
  
  def test_residentialServices(self):
    url = "https://www.lpu.in/student_services/residence.php"
    self.driver.get(url)
    self.driver.execute_script("window.scrollTo(0,1258.4000244140625)")
    response = requests.get(url)
    cont = response.content

    # Parse the HTML content using BeautifulSoup
    cont_html = bs(cont, "html.parser")
    # cont = self.driver.page_source
    # cont_html = bs(cont, "html.parser")
    info = cont_html.find('div', {'class': "col-md-5 facts"})
    print(info.text)
    info2 = cont_html.find('section', {'class':"feature space-section"})
    print(info2.text)
    info2 = cont_html.find('div', {'class':"col-md-12"})
    main=info2.find('p').find_all('a')
    for i in main:
      print(i.get('href'))

    # # self.driver.find_element(By.CSS_SELECTOR, ".col-lg-4 > ul > li:nth-child(1)").click()
    # element = self.driver.find_element(By.CSS_SELECTOR, ".col-lg-4 > ul > li:nth-child(1)")
    # actions = ActionChains(self.driver)
    # actions.move_to_element(element).perform()  # Hover over the element
    # actions.click(element).perform()
    # # cont = self.driver.page_source
    # # cont_html = bs(cont, "html.parser")
    # # about = cont_html.find('ul', {'class': "iconlist iconlist-color"})
    # # print("The following facilities are available in Standard hostel rooms:-")
    # # for i in about.find_all('li'):
    # #   print(i.text)
    # wait = WebDriverWait(self.driver, 10)  # Wait for up to 10 seconds
    # element = wait.until(EC.element_to_be_clickable((By.ID, "ui-id-5")))
    # element.click()
    # time.sleep(3)
    # cont = self.driver.page_source
    # cont_html = bs(cont, "html.parser")
    # # Find the table with class "table table-bordered table-striped"
    # table = cont_html.find_all('tr')
    # for i in table:
    #   print(i)

    
  
if __name__ == '__main__':
    DRIVER_PATH = r"chromedriver.exe"
    browser = TestResidentialServices(DRIVER_PATH)
    browser.test_residentialServices()
# Out:
# 25000+
# ResidentialStudents
#
#
# 60000+
# Meals served per Day
#
#
#
#
# Hostel Facilities
#
#
#
#
#
#
#
# Apartments Style Housing
# Keeping students's requirements in mind, University offers quality
# residence (offering above average necessities) for their living comforts.
#
#
#
#
#
#
#
#
#
# Mess Facility
# All residential facilities have dining halls that provide good
# quality and hygienic food four times a day. Over 60000 meals are prepared each
# day!
#
#
#
#
#
#
#
#
#
#
# Gym Facility
# GYM facility exclusively for hosteller students with subsidized
# Charges (if opted yearly along with hostel). Students can join the facility on a
# yearly basis.
#
#
#
#
#
#
#
#
#
#
# In House Mentor Support
# The residential faculty & staff provide after-hours guidance and
# support to the students, in case they need any academic or life advice.
#
#
#
#
#
#
#
#
#
# In-House Laundry
# In house laundry services are available at a nominal charges to
# students.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
import pytest
import time
import json
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

class TestLibrary():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()
  
  def test_library(self):
    with open("RMS_Academic_Administrative_Issues.txt", "w", encoding="utf-8") as text_file:
      self.driver.get("https://www.lpu.in/academics/libraries.php")
      cont = self.driver.page_source
      cont_html = bs(cont, "html.parser")
      info = cont_html.find_all('div', {'class': "col-md-12"})
      text_file.write(info[1].text + "\n")
      # print(info[1].text)
      info2 = cont_html.find('div', {'id': "section-about"})
      text_file.write(info2.find('h2').text + "\n")
      # print(info2.find('h2').text)
      text_file.write(info2.find('span').text + "\n")
      # print(info2.find('span').text)
      data=info2.find_all('li')
      for i in data:
        text_file.write("* "+i.text + "\n")
        # print("*",i.text)
      info3 = cont_html.find('div', {'id': "section-services"})
      text_file.write(info3.text + "\n")
      # print(info3.text)
      info4 = cont_html.find('div', {'id': "section-resources"})
      text_file.write(info4.text + "\n")
      # print(info4.text)
      info5 = cont_html.find('div', {'class': "heading-block text-center nobottommargin"})
      text_file.write(info5.text + "\n")
      print(info5.text)
      info6 = cont_html.find('div', {'class': "eresources"})
      text_file.write(info6.text + "\n")
      print(info6.text)

      # table ka content hai ye
      info7 = cont_html.find('div',{'id':"section-open-access"})
      text_file.write(info7.text + "\n")
      print(info7.text)

      # main=info7.find('table').find('tbody').find_all('tr')
      # for i in main:
      #   m=1
      #   for j in i.find_all('td'):
      #     if m==1:
      #       print(j.text)
      #       m+=1

      info8 = cont_html.find('div',{'id':"section-opac"})
      text_file.write(info8.text + "\n")
      print(info8.text)
      info9 = cont_html.find('div',{'id':'section-infra'})
      text_file.write(info9.text + "\n")
      print(info9.text)
      info10 = cont_html.find('div',{'id':'section-repository'})
      text_file.write(info10.text + "\n")
      print(info10.text)
      info11 = cont_html.find('div',{'id':'section-contact'})
      text_file.write(info11.text + "\n")
      print(info11.text)

    

  

  

if __name__ == '__main__':
    DRIVER_PATH = r"chromedriver.exe"
    browser = TestLibrary(DRIVER_PATH)
    browser.test_library()
# Out:
# About LPU Library System
# LPU offers a huge Library System with 11 branches. The biggest one is the Central
# Library located in Block-37
#
#
# These E-Resources can be accessed inside and outside the campus. For using them inside, users just need to click on the link of desired E-Resource available at library portal.
#
#
# E-Journals
#
#
# E-Books
#
#
# Databases
#
#
# Institutional Digital Repository
#
#
# National Digital Library
#
#
#
# For providing remote access (outside campus) to the E-Resources, Library
# system uses Mapmyaccess middleware solution. The middleware allows library users to have
# remote online access of various subscribed e-contents with single sign-on the existing
# library credentials i.e. username and password.
#
#
#
#
# Remote Access
#
#
#
#
#
#
#
# Guidelines
#
#
#
#
#
#
#
#
# Open Access
# Free E-Resources
#
#
#
#
# Digital Library
# e-Journals
# e-Books
# Databases
# Patents
# Search Engines
# Theses and Dissertations
#
#
#
#
#
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
import pytest
import time
import json
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

class TestResidentialServices():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()
  
  def test_residentialServices(self):
    self.driver.get("https://www.lpu.in/campus_life/student-organisations.php")
    cont = self.driver.page_source
    cont_html = bs(cont, "html.parser")
    about = cont_html.find_all('div', {'class': "col_one_fourth nobottommargin center"})
    about2 = cont_html.find('div', {'class': "col_one_fourth nobottommargin center col_last"})
    about3 = cont_html.find('div', {'class': "col-lg-2 col-md-3 col-sm-3 clearfix"})
    with open("Student_Organisation.txt", "w", encoding="utf-8") as text_file:
      for i in about:
        text_file.write(i.text + "\n")
        # print(i.text)
      text_file.write(about2.text + "\n\n\n")
      # print(about2.text)
      text_file.write("STUDENT ORGANISATION CATEGORIES" + "\n\n")
      # print("STUDENT ORGANISATION CATEGORIES")
      for i in about3:
        text_file.write(i.text + "\n")
        # print(i.text)
      # print(about3.text)
      about5 = cont_html.find('div', {'id': "processTabs"})
      # print(about5)
      content=about5.find('ul')
      info=about5.find('div')
      for i in content.find_all('li'):
        text_file.write(i.text + "\n")
        # print(i.text)
      for j in info.find_all('div'):
        for m in j.find_all('li'):
          text_file.write("*"+ m.text + "\n")
          # print(m.text)

      
    

    

if __name__ == '__main__':
  DRIVER_PATH = r"chromedriver.exe"
  browser = TestResidentialServices(DRIVER_PATH)
  browser.test_residentialServices()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
import pytest
import time
import json
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import os

class TestAcademicCalendar():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()
  
  def parse_html_table(self,title:str):
    with open("Academic_Calendar.txt", "a", encoding="utf-8") as text_file:
      cont = self.driver.page_source
      cont_html = bs(cont, "html.parser")
      head=cont_html.find_all('h4',{'class':'mb5'})
      text_file.write(head[0].text+"\n")
      text_file.write(title+"\n")
      points=cont_html.find('ul',{'class':'iconlist iconlist-color'})
      
      data=cont_html.find('div', {'class': "table-responsive"})
      main=data.find('table').find('tbody').find_all('tr')
      d={}
      l1=[]
      l2=[]
      l3=[]
      l4=[]
      k=1
      r=1
      for i in main:
        if k==1:
          p=i.text.splitlines()
          l1=p[1:]
          k+=1
        else:
          r=1
          for j in i.find_all('td'):  
            if len(i.find_all('td'))==2:
              if r==1:
                l2.append(j.text)
                r=2
              elif r==2:
                l3.append(j.text)
                l4.append(j.text)
                r=3
            else:
              if r==1:
                l2.append(j.text)
                r=2
              elif r==2:
                l3.append(j.text)
                r=3
              elif r==3:
                l4.append(j.text)
                r=1
      d[l1[0]]=l2
      d[l1[1]]=l3
      d[l1[2]]=l4
      df=pd.DataFrame(d)
      text_file.write(df.to_string()+"\n\n")
      text_file.write(head[1].text+"\n")
      for i in points.find_all('li'):
        text_file.write("*"+i.text+"\n")
      text_file.write("\n\n\n") 
    
  
  def test_academicCalendar(self):  

    #First
    # self.driver.get("https://www.lpu.in/academics/calendar_regular_programmes.php")
    # self.parse_html_table("For all Full-Time programmes")

    #Second
    # self.driver.get("https://www.lpu.in/academics/academic-calendar-for-school-of-law.php")
    # self.parse_html_table("For School of Law")

    #Third
    self.driver.get("https://www.lpu.in/academics/calendar_school_of_education.php")
    self.parse_html_table("For all Full Time Programmes of Education")
    
          

if __name__ == '__main__':
  DRIVER_PATH = r"chromedriver.exe"
  browser = TestAcademicCalendar(DRIVER_PATH)
  browser.test_academicCalendar()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
import pytest
import time
import json
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import os

class TestAcademicCalendar():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()
  
  def parse_html_table(self,title:str):
    with open("Academic_Calendar.txt", "a", encoding="utf-8") as text_file:
      cont = self.driver.page_source
      cont_html = bs(cont, "html.parser")
      head=cont_html.find_all('h4',{'class':'mb5'})
      text_file.write(head[0].text+"\n")
      text_file.write(title+"\n")
      points=cont_html.find('ul',{'class':'iconlist iconlist-color'})
      
      data=cont_html.find('div', {'class': "table-responsive"})
      main=data.find('table').find('tbody').find_all('tr')
      d={}
      l1=[]
      l2=[]
      l3=[]
      k=1
      r=1
      for i in main:
        if k==1:
          p=i.text.splitlines()
          l1=p[1:]
          k+=1
        else:
          r=1
          for j in i.find_all('td'):  
              if r==1:
                  l2.append(j.text)
                  r=2
              elif r==2:
                  l3.append(j.text)
                  r=1
      d[l1[0]]=l2
      d[l1[1]]=l3
      df=pd.DataFrame(d)
      text_file.write(df.to_string()+"\n\n")
      text_file.write(head[1].text+"\n")
      for i in points.find_all('li'):
        text_file.write("*"+i.text+"\n")
      text_file.write("\n\n\n") 
    
  
  def test_academicCalendar(self):  
    #First
    # self.driver.get("https://www.lpu.in/academics/mba.php")
    # self.parse_html_table("For MBA Programme")

    #Second
    # self.driver.get("https://www.lpu.in/academics/specialized-mba.php")
    # self.parse_html_table("For specialized MBA programmes")

    #Third
    # self.driver.get("https://www.lpu.in/academics/b-pharmacy-m-pharmacy.php")
    # self.parse_html_table("For Bachelor of Pharmacy and Master of Pharmacy")

    #Forth
    # self.driver.get("https://www.lpu.in/academics/lsad.php")
    # self.parse_html_table("For Lovely School of Architecture and Design (LSAD)")
    
    #Fifth
    # self.driver.get("https://www.lpu.in/academics/academic-calendar-for-school-of-physical-education-batch.php")
    # self.parse_html_table("For School of Physical Education")

    #Sixth
    # self.driver.get("https://www.lpu.in/academics/academic-calendar-for-school-of-agriculture.php")
    # self.parse_html_table("For School of Agriculture")

    #Seventh
    self.driver.get("https://www.lpu.in/academics/calendar_of_bpt_and_mpt_batch.php")
    self.parse_html_table("For Bachelor of Physiotherapy and Master of Physiotherapy")

    
    
          

if __name__ == '__main__':
  DRIVER_PATH = r"chromedriver.exe"
  browser = TestAcademicCalendar(DRIVER_PATH)
  browser.test_academicCalendar()

# %%
l1=['Name',"Contact Info"]
l2=["Trisha","Kevin","Hareen","Gokul"]
l3=[1234,1234,1234,6798]
d={}
d[l1[0]]=l2
d[l1[1]]=l3
print(pd.DataFrame(d))
# Out:
#      Name  Contact Info
# 0  Trisha          1234
# 1   Kevin          1234
# 2  Hareen          1234
# 3   Gokul          6798

# %%
d
# Out:
# {'Name': ['Trisha', 'Kevin', 'Hareen', 'Gokul'],
#  'Contact Info': [1234, 1234, 1234, 6798]}

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
import pytest
import time
import json
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

class TestResidentialServices():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  def teardown_method(self, method):
    self.driver.quit()
    
  def parse_html_table(self,data):
    main=data.find('table').find('tbody').find_all('tr')
    d={}
    l1=[]
    l2=[]
    l3=[]
    l4=[]
    l5=[]
    k=1
    r=1
    for i in main:
      if k==1:
        p=i.text.splitlines()
        print("p: ",p)
        l1=p[1:]
        k+=1
      else:
        r=1
        values=i.text.splitlines()
        for j in values[1:]:  
            if r==1:
              l2.append(j)
              r=2
            elif r==2:
              l3.append(j)
              r=3
            elif r==3:
              l4.append(j)
              r=4
            elif r==4:
              l5.append(j)
              r=1
    print("l1: ",len(l1))
    print(len(l2))
    print(len(l3))
    print(len(l4))
    print(len(l5))
    d[l1[0]]=l2
    d[l1[1]]=l3
    d[l1[2]]=l4
    d[l1[3]]=l5
    df=pd.DataFrame(d)
    print(df.to_string())
    
  
  def test_residentialServices(self):
    self.driver.get("https://www.lpu.in/student_services/residence.php")
    self.driver.execute_script("window.scrollTo(0,1258.4000244140625)")
    element = self.driver.find_element(By.CSS_SELECTOR, ".col-lg-4 > ul > li:nth-child(1)")
    actions = ActionChains(self.driver)
    actions.move_to_element(element).perform()  # Hover over the element
    actions.click(element).perform()
    wait = WebDriverWait(self.driver, 10)  # Wait for up to 10 seconds
    element = wait.until(EC.element_to_be_clickable((By.ID, "ui-id-5")))
    element.click()
    cont = self.driver.page_source
    cont_html = bs(cont, "html.parser")
    about = cont_html.find('div',{'class': "table-responsive"})
    self.parse_html_table(about)
    time.sleep(5)
    # self.driver.find_element(By.ID, "ui-id-6").click()
    # self.driver.find_element(By.ID, "ui-id-7").click()
    # self.driver.find_element(By.ID, "ui-id-8").click()
    # self.driver.find_element(By.ID, "apartments-tab").click()
    # self.driver.find_element(By.ID, "ui-id-11").click()
    # self.driver.find_element(By.ID, "ui-id-12").click()
    # self.driver.find_element(By.ID, "ui-id-13").click()
    # self.driver.find_element(By.ID, "ui-id-14").click()

    
if __name__ == '__main__':
    DRIVER_PATH = r"chromedriver.exe"
    browser = TestResidentialServices(DRIVER_PATH)
    browser.test_residentialServices()
# Out:
# p:  ['', 'Room Category', 'Charges for Full Academic Session with EDB#', 'Charges for Full Academic Session without EDB#', 'Free Electricity Units']
# l1:  4
# 2
# 2
# 2
# 2
#   Room Category Charges for Full Academic Session with EDB# Charges for Full Academic Session without EDB# Free Electricity Units
# 0            AC                                 Rs. 90000/-                                   Rs. 100000/-                    500
# 1      Non- AC*                                 Rs. 80000/-                                    Rs. 90000/-                    300

# %%
#Code for realtime Announcements

import pytest
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup as bs
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
import re
import pandas as pd
from selenium.webdriver.support import expected_conditions as EC
import os
from datetime import date

import schedule
import time

class TestTry1():
  driver, service= None, None
  def __init__(self):
    self.vars = {}

  def test_try1(self):
    self.driver = webdriver.Chrome(executable_path=self.driver_path)
  
  def teardown_method(self, method):
    self.driver.quit()
  
  def wait_for_window(self, timeout = 2):
    time.sleep(round(timeout / 1000))
    wh_now = self.driver.window_handles
    wh_then = self.vars["window_handles"]
    if len(wh_now) > len(wh_then):
      return set(wh_now).difference(set(wh_then)).pop()
  
  def test_try1(self):
    DRIVER_PATH = r"chromedriver.exe"
    self.service = Service(DRIVER_PATH)
    self.driver = webdriver.Chrome(service=self.service)
    # self.driver.get("https://ums.lpu.in/lpuums/LoginNew.aspx")
    browser.get("https://ums.lpu.in/lpuums/LoginNew.aspx")
    self.driver.set_window_size(768, 864)
    # self.driver.find_element(By.ID, "txtU").click()
    self.driver.find_element(By.ID, "txtU").send_keys("12101718")
    try:
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    except Exception as e:
      #print(f"Error finding or clicking submit button: {e}")
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    
    self.driver.find_element(By.ID, "iBtnLogins150203125").click()
    self.driver.execute_script("window.scrollTo(0,90.4000015258789)")
    self.driver.execute_script("window.scrollTo(0,1744.800048828125)")
    self.driver.execute_script("window.scrollTo(0,1972.800048828125)")
    self.vars["window_handles"] = self.driver.window_handles
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.LINK_TEXT, "View All Announcements"))
      )
      element.click()
    except:
      driver.quit()
    self.vars["win8781"] = self.wait_for_window(2000)
    self.driver.switch_to.window(self.vars["win8781"])
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_ddlSearchBy_Arrow").click()
    # try:
    #   element=WebDriverWait(self.driver,5).until(
    #       EC.presence_of_element_located((By.CSS_SELECTOR, ".rcbHovered"))
    #   )
    #   element.click()
    # except:
    #   self.driver.quit()
    # self.driver.find_element().click()
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_ddlSearchBy_Input").send_keys("Uploaded By")
    time.sleep(3)
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.CSS_SELECTOR, ".rcbHovered"))
      )
      element.click()
    except:
      self.driver.quit()
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.ID,"ctl00_ContentPlaceHolder1_RadDatePicker1_popupButton"))
      )
      element.click()
    except:
      self.driver.quit()
    today = date.today()
    y=today.strftime("%Y-%m-%d")
    x_path="//a[normalize-space()='"+y[-2:]+"']"
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.XPATH,x_path))
      )
      element.click()
    except:
      self.driver.quit()
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_RadComboBox1_Input").send_keys("Between")
    time.sleep(10)
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_btnShow").click()

    cont=self.driver.page_source
    cont_html = bs(cont, "html.parser")
    # print(cont_html)
    commentboxes1 = cont_html.find_all('tr', {'class': "rgRow"})
    list1=[]
    for comment in commentboxes1:
      k=comment.text
      cleaned_text = re.sub(r"\s+", " ", k)
      cleaned_text = cleaned_text.replace("\xa0", " ")
      list1.append(cleaned_text)
      
    commentboxes2 = cont_html.find_all('tr', {'class': "rgAltRow"})
    for comment in commentboxes2:
      k=comment.text
      cleaned_text = re.sub(r"\s+", " ", k)
      cleaned_text = cleaned_text.replace("\xa0", " ")
      list1.append(cleaned_text)
    print(list1)

    with open("Dynamic_Announcements.txt", "w", encoding="utf-8") as text_file:
      for item in list1:
        text_file.write("*"+item + "\n\n\n")  # Add newline character for readability

      
   
    
    
    # self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_RadDatePicker1_popupButton").click()
    # self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_ddlSearchBy_Input").send_keys("Uploaded By")
    
    time.sleep(10)
    # okay = Select(pp)
    # okay.select_by_visible_text("Date Wise")
    
    
  
if __name__ == '__main__':
  
  browser = TestTry1()
  # browser.test_try1()
  schedule.every().day.at("20:09").do(browser.test_try1,browser)  # Remove parentheses
  while 1:
    schedule.run_pending()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[20], line 155
#     153 schedule.every().day.at("20:09").do(browser.test_try1,browser)  # Remove parentheses
#     154 while 1:
# --> 155   schedule.run_pending()
#     156   time.sleep(1)
#
# File c:\TURBOC3\BIN\Datascience\Flipkart_Review\venv\Lib\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File c:\TURBOC3\BIN\Datascience\Flipkart_Review\venv\Lib\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# ...

# %%
#Code for Static Announcements

import pytest
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup as bs
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
import re
import pandas as pd
from selenium.webdriver.support import expected_conditions as EC
import os
from datetime import date

class TestTry1():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}
  
  def teardown_method(self, method):
    self.driver.quit()
  
  def wait_for_window(self, timeout = 2):
    time.sleep(round(timeout / 1000))
    wh_now = self.driver.window_handles
    wh_then = self.vars["window_handles"]
    if len(wh_now) > len(wh_then):
      return set(wh_now).difference(set(wh_then)).pop()

  def Store_data(self):
    cont=self.driver.page_source
    cont_html = bs(cont, "html.parser")
    # print(cont_html)
    commentboxes1 = cont_html.find_all('tr', {'class': "rgRow"})
    list1=[]
    for comment in commentboxes1:
      k=comment.text
      cleaned_text = re.sub(r"\s+", " ", k)
      cleaned_text = cleaned_text.replace("\xa0", " ")
      list1.append(cleaned_text)
      
    commentboxes2 = cont_html.find_all('tr', {'class': "rgAltRow"})
    for comment in commentboxes2:
      k=comment.text
      cleaned_text = re.sub(r"\s+", " ", k)
      cleaned_text = cleaned_text.replace("\xa0", " ")
      list1.append(cleaned_text)
    print(list1)
    with open("Announcements.txt", "a", encoding="utf-8") as text_file:
      for item in list1:
        text_file.write("*"+item + "\n\n\n")  # Add newline character for readability

  def test_try1(self):
    self.driver.get("https://ums.lpu.in/lpuums/LoginNew.aspx")
    self.driver.set_window_size(768, 864)
    # self.driver.find_element(By.ID, "txtU").click()
    self.driver.find_element(By.ID, "txtU").send_keys("12101718")
    try:
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    except Exception as e:
      #print(f"Error finding or clicking submit button: {e}")
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    
    self.driver.find_element(By.ID, "iBtnLogins150203125").click()

    try:
      element = WebDriverWait(self.driver, 10).until(EC.element_to_be_clickable((By.ID, "chkReadMessage")))
      if element:
        try:
          actions = ActionChains(self.driver)
          actions.move_to_element(element).perform()
          element.click()  # Click on the element directly (without find_element again)
        except Exception as e:
          print("Element with ID 'chkReadMessage' not found or not interactable within 10 seconds.")

        try:
          element = WebDriverWait(self.driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "enableClosedialog")))
          actions = ActionChains(self.driver)
          actions.move_to_element(element).perform()
          element.click()  # Click on the element directly (without find_element again)

        except Exception as e:
          element = WebDriverWait(self.driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "enableClosedialog")))
          actions = ActionChains(self.driver)
          actions.move_to_element(element).perform()
          element.click()
          print("Element with ID 'chkReadMessage' not found or not interactable within 10 seconds.",e)
      else:
        print("Element with ID 'chkReadMessage' not found. Skipping actions.")
    except Exception as e:
      print("Element with ID 'chkReadMessage' not found or not interactable within 10 seconds.")

    self.driver.execute_script("window.scrollTo(0,90.4000015258789)")
    self.driver.execute_script("window.scrollTo(0,1744.800048828125)")
    self.driver.execute_script("window.scrollTo(0,1972.800048828125)")
    self.vars["window_handles"] = self.driver.window_handles
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.LINK_TEXT, "View All Announcements"))
      )
      element.click()
    except:
      driver.quit()
    self.vars["win8781"] = self.wait_for_window(2000)
    self.driver.switch_to.window(self.vars["win8781"])
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_ddlSearchBy_Arrow").click()
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_ddlSearchBy_Input").send_keys("Uploaded By")
    time.sleep(3)
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.CSS_SELECTOR, ".rcbHovered"))
      )
      element.click()
    except:
      self.driver.quit()
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.ID,"ctl00_ContentPlaceHolder1_RadDatePicker1_popupButton"))
      )
      element.click()
    except:
      self.driver.quit()
    today = date.today()
    y=today.strftime("%Y-%m-%d")
    x_path="//a[normalize-space()='"+y[-2:]+"']"
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.XPATH,x_path))
      )
      element.click()
    except:
      self.driver.quit()
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_RadComboBox1_Input").send_keys("equal to")
    time.sleep(3)
    
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_btnShow").click()
    self.Store_data()

    

    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(2) > .aspLabel").click()
    self.Store_data()
    
    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(3) > .aspLabel").click()
    self.Store_data()
    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(4) > .aspLabel").click()
    self.Store_data()
    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(5) > .aspLabel").click()
    self.Store_data()
    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(6) > .aspLabel").click()
    self.Store_data()
    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(7) > .aspLabel").click()
    self.Store_data()
    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(8) > .aspLabel").click()
    self.Store_data()
    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(9) > .aspLabel").click()
    self.Store_data()
    self.driver.find_element(By.CSS_SELECTOR, "a:nth-child(10) > .aspLabel").click()
    self.Store_data()

      
   
    
    
    
    
    
  
if __name__ == '__main__':
  DRIVER_PATH = r"chromedriver.exe"
  browser = TestTry1(DRIVER_PATH)
  browser.test_try1()
# Out:
# Element with ID 'chkReadMessage' not found or not interactable within 10 seconds.
# ...

# %%
#Code for realtime Announcements

import pytest
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup as bs
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.select import Select
import re
import pandas as pd
from selenium.webdriver.support import expected_conditions as EC
import os
from datetime import date

import time

class TestTry1():
  driver, service= None, None
  def __init__(self, driver: str):
    self.service = Service(driver)
    self.driver = webdriver.Chrome(service=self.service)
    self.vars = {}

  
  def teardown_method(self, method):
    self.driver.quit()
  
  def wait_for_window(self, timeout = 2):
    time.sleep(round(timeout / 1000))
    wh_now = self.driver.window_handles
    wh_then = self.vars["window_handles"]
    if len(wh_now) > len(wh_then):
      return set(wh_now).difference(set(wh_then)).pop()
  
  def test_try1(self):
    
    self.driver.get("https://ums.lpu.in/lpuums/LoginNew.aspx")
    self.driver.set_window_size(768, 864)
    # self.driver.find_element(By.ID, "txtU").click()
    self.driver.find_element(By.ID, "txtU").send_keys("12101718")
    try:
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    except Exception as e:
      #print(f"Error finding or clicking submit button: {e}")
      search2 = self.driver.find_element(by=By.ID, value="TxtpwdAutoId_8767")
      search2.send_keys("Hatyarr5@")
    
    self.driver.find_element(By.ID, "iBtnLogins150203125").click()
    self.driver.execute_script("window.scrollTo(0,90.4000015258789)")
    self.driver.execute_script("window.scrollTo(0,1744.800048828125)")
    self.driver.execute_script("window.scrollTo(0,1972.800048828125)")
    self.vars["window_handles"] = self.driver.window_handles
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.LINK_TEXT, "View All Announcements"))
      )
      element.click()
    except:
      driver.quit()
    self.vars["win8781"] = self.wait_for_window(2000)
    self.driver.switch_to.window(self.vars["win8781"])
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_ddlSearchBy_Arrow").click()
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_ddlSearchBy_Input").send_keys("Uploaded By")
    time.sleep(3)
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.CSS_SELECTOR, ".rcbHovered"))
      )
      element.click()
    except:
      self.driver.quit()
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.ID,"ctl00_ContentPlaceHolder1_RadDatePicker1_popupButton"))
      )
      element.click()
    except:
      self.driver.quit()
    today = date.today()
    y=today.strftime("%Y-%m-%d")
    x_path="//a[normalize-space()='"+y[-2:]+"']"
    try:
      element=WebDriverWait(self.driver,5).until(
          EC.presence_of_element_located((By.XPATH,x_path))
      )
      element.click()
    except:
      self.driver.quit()
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_RadComboBox1_Input").send_keys("Between")
    time.sleep(10)
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_btnShow").click()

    cont=self.driver.page_source
    cont_html = bs(cont, "html.parser")
    # print(cont_html)
    commentboxes1 = cont_html.find_all('tr', {'class': "rgRow"})
    list1=[]
    for comment in commentboxes1:
      k=comment.text
      cleaned_text = re.sub(r"\s+", " ", k)
      cleaned_text = cleaned_text.replace("\xa0", " ")
      list1.append(cleaned_text)
      
    commentboxes2 = cont_html.find_all('tr', {'class': "rgAltRow"})
    for comment in commentboxes2:
      k=comment.text
      cleaned_text = re.sub(r"\s+", " ", k)
      cleaned_text = cleaned_text.replace("\xa0", " ")
      list1.append(cleaned_text)
    print(list1)

    with open("Dynamic_Announcements.txt", "w", encoding="utf-8") as text_file:
      for item in list1:
        text_file.write("*"+item + "\n\n\n")  
    
    
    
  
if __name__ == '__main__':
  
  DRIVER_PATH = r"chromedriver.exe"
  browser = TestTry1(DRIVER_PATH)
  browser.test_try1()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[1], line 130
#     127 if __name__ == '__main__':
#     129   DRIVER_PATH = r"chromedriver.exe"
# --> 130   browser = TestTry1(DRIVER_PATH)
#     131   browser.test_try1()
#
# Cell In[1], line 28, in TestTry1.__init__(self, driver)
#      26 def __init__(self, driver: str):
#      27   self.service = Service(driver)
# ---> 28   self.driver = webdriver.Chrome(service=self.service)
#      29   self.vars = {}
#
# File c:\TURBOC3\BIN\Datascience\Flipkart_Review\venv\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
# ...

# %%
from flask import Flask, jsonify
app = Flask(__name__)

@app.route('/')
def hello_world():
    return "Hello, World!"

if __name__ == "__main__":
    app.run(host='127.0.0.1', port=8000, debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
